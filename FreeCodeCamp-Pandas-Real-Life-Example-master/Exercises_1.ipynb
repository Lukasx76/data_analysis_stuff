# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv(
    'data/sales_data.csv',
    parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
# 4  Hitch Rack - 4-Bike               4         45         120     238   180
#
#    Revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Why don't you try with `.mean()`

# %%
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales['Customer_Age'].plot(kind='kde', figsize=(5,3))

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
sales['Order_Quantity'].mean()

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
#sales['Order_Quantity'].plot(kind='box', figsize=(14,6))
sales['Order_Quantity'].plot(kind='hist', figsize=(14,6))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales['Year'].value_counts()

# %%
sales['Year'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sales['Year'].value_counts()
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here
sales['Year'].value_counts().plot(kind='pie', figsize=(13,6))
# Out:
# <AxesSubplot: ylabel='Year'>

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
sales['Month'].value_counts()
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %%
sales['Month'].value_counts()

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales['Month'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
sales['Country'].value_counts()
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %%
sales['Country'].value_counts().head(1)

# %%
sales['Country'].value_counts()

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales['Country'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here
sales['Product'].unique()
# Out:
# ['Accessories' 'Clothing' 'Bikes']

# %%
#sales.loc[:, 'Product'].unique()

sales[''].unique()

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here
sales['Product'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', colorbar=True)
# Out:
# <AxesSubplot: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales[['Order_Quantity', 'Profit']]
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(10,6))
# Out:
# <AxesSubplot: xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <AxesSubplot: xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here
sales[['Profit', 'Country']].boxplot(by='Country')
# Out:
# <AxesSubplot: title={'center': 'Profit'}, xlabel='[Country]'>

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(12,8))
# Out:
# <AxesSubplot: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here
sales['Calculate_Date'] = pd.to_datetime(sales[['Year', 'Month', 'Day']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\_libs\lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "November"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 # your code goes here
# ----> 2 sales['Calculate_Date'] = pd.to_datetime(sales[['Year', 'Month', 'Day']])
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\tools\datetimes.py:1071, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1071     result = _assemble_from_unit_mappings(arg, errors, tz)
#    1072 elif isinstance(arg, Index):
#    1073     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\tools\datetimes.py:1210, in _assemble_from_unit_mappings(arg, errors, tz)
#    1205         values = values.astype("int64", copy=False)
#    1206     return values
#    1208 values = (
#    1209     coerce(arg[unit_rev["year"]]) * 10000
# -> 1210     + coerce(arg[unit_rev["month"]]) * 100
#    1211     + coerce(arg[unit_rev["day"]])
#    1212 )
#    1213 try:
#    1214     values = to_datetime(values, format="%Y%m%d", errors=errors, utc=tz)
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\tools\datetimes.py:1201, in _assemble_from_unit_mappings.<locals>.coerce(values)
#    1199 def coerce(values):
#    1200     # we allow coercion to if errors allows
# -> 1201     values = to_numeric(values, errors=errors)
#    1203     # prevent overflow in case of int8 or int16
#    1204     if is_integer_dtype(values):
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\tools\numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\_libs\lib.pyx:2411, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "November" at position 0

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here
sales['Calculated_Date'] = pd.to_datetime(sales.Calculated_Date)

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here
sales['Calculated_Date'].value_counts().plot()
# Out:
# <AxesSubplot: >

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
sales['Revenue'] = sales['Revenue'] + 50

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here
sales.loc[(sales.Country == 'Canada') | (sales.Country =='France')]
# Out:
#              Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0      2013-11-26   26   November  2013            19           Youth (<25)
# 1      2015-11-26   26   November  2015            19           Youth (<25)
# 14     2013-08-02    2     August  2013            29  Young Adults (25-34)
# 15     2015-08-02    2     August  2015            29  Young Adults (25-34)
# 16     2013-09-02    2  September  2013            29  Young Adults (25-34)
# ...           ...  ...        ...   ...           ...                   ...
# 112979 2015-09-08    8  September  2015            31  Young Adults (25-34)
# 113000 2014-07-27   27       July  2014            34  Young Adults (25-34)
# 113001 2016-07-27   27       July  2016            34  Young Adults (25-34)
# 113034 2014-03-04    4      March  2014            37        Adults (35-64)
# 113035 2016-03-04    4      March  2016            37        Adults (35-64)
#
#        Customer_Gender Country             State Product_Category  \
# 0                    M  Canada  British Columbia      Accessories
# 1                    M  Canada  British Columbia      Accessories
# 14                   M  Canada  British Columbia      Accessories
# 15                   M  Canada  British Columbia      Accessories
# 16                   M  Canada  British Columbia      Accessories
# ...                ...     ...               ...              ...
# 112979               M  France           Essonne         Clothing
# 113000               M  France           Essonne         Clothing
# 113001               M  France           Essonne         Clothing
# 113034               F  France     Seine (Paris)         Clothing
# 113035               F  France     Seine (Paris)         Clothing
#
#        Sub_Category              Product  Order_Quantity  Unit_Cost  \
# 0        Bike Racks  Hitch Rack - 4-Bike               8         45
# 1        Bike Racks  Hitch Rack - 4-Bike               8         45
# 14       Bike Racks  Hitch Rack - 4-Bike               5         45
# 15       Bike Racks  Hitch Rack - 4-Bike               7         45
# 16       Bike Racks  Hitch Rack - 4-Bike               2         45
# ...             ...                  ...             ...        ...
# 112979        Vests      Classic Vest, M              28         24
# 113000        Vests      Classic Vest, M               6         24
# 113001        Vests      Classic Vest, M               7         24
# 113034        Vests      Classic Vest, L              24         24
# 113035        Vests      Classic Vest, L              23         24
#
#         Unit_Price  Profit  Cost  Revenue Calculated_Date
# 0              120     590   360     1000      2013-11-26
# 1              120     590   360     1000      2015-11-26
# 14             120     369   225      644      2013-08-02
# 15             120     517   315      882      2015-08-02
# 16             120     148    90      288      2013-09-02
# ...            ...     ...   ...      ...             ...
# 112979          64    1048   672     1770      2015-09-08
# 113000          64     225   144      419      2014-07-27
# 113001          64     262   168      480      2016-07-27
# 113034          64     684   576     1310      2014-03-04
# 113035          64     655   552     1257      2016-03-04
#
# [25176 rows x 19 columns]

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')]
# Out:
#           Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0   2013-11-26   26   November  2013            19           Youth (<25)
# 1   2015-11-26   26   November  2015            19           Youth (<25)
# 14  2013-08-02    2     August  2013            29  Young Adults (25-34)
# 15  2015-08-02    2     August  2015            29  Young Adults (25-34)
# 16  2013-09-02    2  September  2013            29  Young Adults (25-34)
# ..         ...  ...        ...   ...           ...                   ...
# 495 2016-04-13   13      April  2016            40        Adults (35-64)
# 496 2014-04-30   30      April  2014            40        Adults (35-64)
# 497 2016-04-30   30      April  2016            40        Adults (35-64)
# 512 2013-08-25   25     August  2013            26  Young Adults (25-34)
# 513 2015-08-25   25     August  2015            26  Young Adults (25-34)
#
#     Customer_Gender Country             State Product_Category Sub_Category  \
# 0                 M  Canada  British Columbia      Accessories   Bike Racks
# 1                 M  Canada  British Columbia      Accessories   Bike Racks
# 14                M  Canada  British Columbia      Accessories   Bike Racks
# 15                M  Canada  British Columbia      Accessories   Bike Racks
# 16                M  Canada  British Columbia      Accessories   Bike Racks
# ..              ...     ...               ...              ...          ...
# 495               M  Canada  British Columbia      Accessories   Bike Racks
# 496               M  Canada  British Columbia      Accessories   Bike Racks
# 497               M  Canada  British Columbia      Accessories   Bike Racks
# 512               M  Canada  British Columbia      Accessories   Bike Racks
# 513               M  Canada  British Columbia      Accessories   Bike Racks
#
#                  Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0    Hitch Rack - 4-Bike               8         45         120     590   360
# 1    Hitch Rack - 4-Bike               8         45         120     590   360
# 14   Hitch Rack - 4-Bike               5         45         120     369   225
# 15   Hitch Rack - 4-Bike               7         45         120     517   315
# 16   Hitch Rack - 4-Bike               2         45         120     148    90
# ..                   ...             ...        ...         ...     ...   ...
# 495  Hitch Rack - 4-Bike               2         45         120     148    90
# 496  Hitch Rack - 4-Bike               6         45         120     443   270
# 497  Hitch Rack - 4-Bike               5         45         120     369   225
# 512  Hitch Rack - 4-Bike               3         45         120     221   135
# 513  Hitch Rack - 4-Bike               2         45         120     148    90
#
#      Revenue Calculated_Date
# 0       1000      2013-11-26
# 1       1000      2015-11-26
# 14       644      2013-08-02
# 15       882      2015-08-02
# 16       288      2013-09-02
# ..       ...             ...
# 495      288      2016-04-13
# 496      763      2014-04-30
# 497      644      2016-04-30
# 512      406      2013-08-25
# 513      288      2015-08-25
#
# [104 rows x 19 columns]

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states
# Out:
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: State, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
france_states.plot(figsize=(14,6))
# Out:
# <AxesSubplot: >

# %%
france_states.plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
sales['Product_Category'].value_counts()
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %%
sales['Product_Category'].value_counts()

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(12,5))
# Out:
# <AxesSubplot: ylabel='Product_Category'>

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here

sales['Product_Category'].unique()
# Out:
# array(['Accessories', 'Clothing', 'Bikes'], dtype=object)

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

accessories
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here

accessories.plot(figsize=(12,6))
# Out:
# <AxesSubplot: >

# %%
accessories.plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

sales.Product_Category
# Out:
# 0         Accessories
# 1         Accessories
# 2         Accessories
# 3         Accessories
# 4         Accessories
#              ...
# 113031       Clothing
# 113032       Clothing
# 113033       Clothing
# 113034       Clothing
# 113035       Clothing
# Name: Product_Category, Length: 113036, dtype: object

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
bikes.plot(kind='pie', figsize=(12,6))
# Out:
# <AxesSubplot: ylabel='Sub_Category'>

# %%
bikes.plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here
sales.Customer_Gender.value_counts()
# Out:
# M    58312
# F    54724
# Name: Customer_Gender, dtype: int64

# %%
sales['Customer_Gender'].value_counts()

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here

more_than_500 = sales.loc[(sales['Revenue'] > 500) & (sales['Customer_Gender'] == 'M')]

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# 112073        Vests  Touring-1000 Yellow, 50              29       1482
# 112072        Vests  Touring-1000 Yellow, 50              27       1482
# 71129    Road Bikes         Road-150 Red, 48               4       2171
# 70307    Road Bikes         Road-150 Red, 62               4       2171
# 70601    Road Bikes         Road-150 Red, 62               4       2171
#
#         Unit_Price  Profit   Cost  Revenue Calculated_Date
# 112073        2384   15096  42978    58124      2015-07-24
# 112072        2384   14055  40014    54119      2013-07-24
# 71129         3578    5628   8684    14362      2011-07-08
# 70307         3578    5485   8684    14219      2011-04-30
# 70601         3578    5485   8684    14219      2011-09-30

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here

sales.Revenue.max()
# Out:
# 58124

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here
# Out:
# C:\Users\Natan Feitoza Gomes\AppData\Local\Temp\ipykernel_13188\2700698695.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   mean_of_10k = sales.loc[sales['Revenue'] > 10000].mean()
# C:\Users\Natan Feitoza Gomes\AppData\Local\Temp\ipykernel_13188\2700698695.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_of_10k = sales.loc[sales['Revenue'] > 10000].mean()
# Day                  16.728814
# Year               2012.824859
# Customer_Age         35.271186
# Order_Quantity        3.689266
# Unit_Cost          2152.576271
# Unit_Price         3556.762712
# Profit             4151.485876
# Cost               7748.853107
# Revenue           11950.338983
# dtype: float64

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 3.689265536723164

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 11.914539380997528

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 5015

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May','July')

sales.loc[cond].shape[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 # your code goes here
# ----> 2 cond = (sales['Year'] == 2016) & (sales['Month'] == 'May','July')
#       4 sales.loc[cond].shape[0]
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\arraylike.py:72, in OpsMixin.__and__(self, other)
#      70 @unpack_zerodim_and_defer("__and__")
#      71 def __and__(self, other):
# ---> 72     return self._logical_method(other, operator.and_)
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\series.py:6254, in Series._logical_method(self, other, op)
#    6251 lvalues = self._values
#    6252 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6254 res_values = ops.logical_op(lvalues, rvalues, op)
#    6255 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\ops\array_ops.py:385, in logical_op(left, right, op)
#     383 if isinstance(rvalues, np.ndarray):
#     384     is_other_int_dtype = is_integer_dtype(rvalues.dtype)
# --> 385     rvalues = rvalues if is_other_int_dtype else fill_bool(rvalues, lvalues)
#     387 else:
#     388     # i.e. scalar
#     389     is_other_int_dtype = lib.is_integer(rvalues)
#
# File c:\Users\Natan Feitoza Gomes\Desktop\pythonCourseProject\dataScienceStuffAndProjects\lib\site-packages\pandas\core\ops\array_ops.py:364, in logical_op.<locals>.fill_bool(x, left)
#     361         x[mask] = False
#     363 if left is None or is_bool_dtype(left.dtype):
# --> 364     x = x.astype(bool)
#     365 return x
#
# ValueError: setting an array element with a sequence.

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]
# Out:
# 12164

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))
# Out:
# <AxesSubplot: title={'center': 'Profit'}, xlabel='[Month]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here
sales['Unit_Price'] += sales['Unit_Price'] * 0.072

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
